# %%
# Standard Library
# Python's Standard Library is a vast collection of modules and packages that come bundled with Python, providing a wide range of functionalities out of the box.
# Here's an overview of some of the most commonly used modules and packages in the Python Standard Library.

# %%
import array
arr=array.array('i', [1,2,3,4])
print(arr)
# Out:
# array('i', [1, 2, 3, 4])

# %%
import math

print(math.sqrt(56))
print(math.pi)
# Out:
# 7.483314773547883
# 3.141592653589793

# %%
# Random

import random
print(random.randint(1, 10))
print(random.choice(['apple', 'banana', 'cherry']))
# Out:
# 10
# banana

# %%
# File and Directory Access

import os
print(os.getcwd())
# Out:
# c:\Users\punit\github\python-bookish-giggle\05. Modules

# %%
# Creating a Directory
os.mkdir('test_dir')

# %%
# High Level Operations on Files and Collection of Files

import shutil
shutil.copyfile('source.txt', 'destination.txt')
# Out:
# 'destination.txt'

# %%
# Data Serialization

import json
data={'name':'Punit','age':25}

json_str = json.dumps(data)
print(json_str)
print(type(json_str))

parsed_data = json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "Punit", "age": 25}
# <class 'str'>
# {'name': 'Punit', 'age': 25}
# <class 'dict'>

# %%
# CSV

import csv

with open('example.csv', mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['name', 'age'])
    writer.writerow(['Punit', 25])

with open('example.csv', mode='r') as file:
    reader= csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['Punit', '25']

# %%
# DateTime
from datetime import datetime, timedelta

now = datetime.now()
print(now)

yesterday = now-timedelta(days=1)
print(yesterday)
# Out:
# 2026-06-15 23:09:53.304911
# 2026-06-14 23:09:53.304911

# %%
# Time 

import time
print(time.time())

time.sleep(2)
print(time.time())
# Out:
# 1781545193.3393614
# 1781545195.3461564

# %%
# Regular Expression

import re

pattern = r'\d+'
text = 'My age is 25.'
match = re.search(pattern, text)
print(match.group())
# Out:
# 25
