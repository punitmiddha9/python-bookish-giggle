# %%
# Classes and Objects
# Object-Oriented Programming (OOP) is a programming paradigm that uses "objects" to design applications and computer programs. 
# OOP allows for modeling real-world scenarios using classes and objects. This lesson covers the basics of creating classes and objects, including instance variables and methods.

# %%
# A class is a blue print for creating objects. 
# Attributes, methods

class car:
    pass

audi=car()
bmw=car()

print(type(audi))
# Out:
# <class '__main__.car'>

# %%
print(audi)
# Out:
# <__main__.car object at 0x00000294D6FCF160>

# %%
audi.windows=4

print(audi.windows)
# Out:
# 4

# %%
tata=car()
tata.doors=4
print(tata.windows)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 3
#       1 tata=car()
#       2 tata.doors=4
# ----> 3 print(tata.windows)
#
# AttributeError: 'car' object has no attribute 'windows'

# %%
dir(tata)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'doors']

# %%
# Instance Varibles and Methods

class Dog:
    # Constructor
    def __init__(self, name, age):
        self.name = name
        self.age = age


# Create Objects

dog1 = Dog("Buddy", 3)
print(dog1)
print(dog1.name)
print(dog1.age)
# Out:
# <__main__.Dog object at 0x00000294D833C8B0>
# Buddy
# 3

# %%
dog2 = Dog("Chikki", 2)
print(dog2)
print(dog2.name)
print(dog2.age)
# Out:
# <__main__.Dog object at 0x00000294D830CEE0>
# Chikki
# 2

# %%
# Instance Methods

class Dog:
    def __init__(self, name, age):
        self.name = name
        self.age = age
    
    def bark(self):
        print(f"{self.name} says Woof.")

dog1=Dog("Buddy", 3)
dog1.bark()
# Out:
# Buddy says Woof.

# %%
# Modeling a Bank Account

# Define a class for Bank Account

class BankAccount:
    def __init__(self, owner, balance=0):
        self.owner = owner
        self.balance = balance

    def deposit(self, amt):
        self.balance += amt
        print(f"{amt} is deposited. New Balance is {self.balance}")

    def withdraw(self, amt):
        if amt>self.balance:
            print("Insufficient Balance")
        else:
            self.balance -= amt
            print(f"{amt} is Withdrawn. New Balance is {self.balance}")

    def get_balance(self):
        return self.balance
    

account=BankAccount("Punit", 5000)
print(account.balance)
# Out:
# 5000

# %%
account.deposit(100)
# Out:
# 100 is deposited. New Balance is 5100

# %%
account.withdraw(2500)
# Out:
# 2500 is Withdrawn. New Balance is 2600

# %%
print(account.get_balance())
# Out:
# 2600
